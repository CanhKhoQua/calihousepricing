# %%
# %mamba install pandas
# %mamba install numpy
# %mamba install matplotlib
# %mamba install scikit-learn
# %mamba install seaborn
# Out:
# mambajs 0.19.13
#
# Specs: xeus-python, numpy, matplotlib, pillow, ipywidgets>=8.1.6, ipyleaflet, scipy, pandas
# Channels: emscripten-forge, conda-forge
#
# Solving environment...
# Solving took 1.6155 seconds
#   Name                          Version                       Build                         Channel
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# + pandas                        3.0.2                         np22py313h9d9dc1e_0           emscripten-forge
# + python-tzdata                 2026.1                        pyhd8ed1ab_0                  conda-forge
# - pip                           25.3                          pyh145f28c_0                  conda-forge
# mambajs 0.19.13
#
# Specs: xeus-python, numpy, matplotlib, pillow, ipywidgets>=8.1.6, ipyleaflet, scipy, pandas
# Channels: emscripten-forge, conda-forge
#
# Solving environment...
# Solving took 1.2543999999761581 seconds
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import joblib

# %matplotlib inline

# %% [markdown]
# ## Load the California House Pricing Dataset

# %%
from sklearn.datasets import fetch_california_housing
cali = fetch_california_housing()

# %%
cali.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'feature_names', 'DESCR'])

# %%
## Check the description of the dataset
print(cali.DESCR)
# Out:
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 20640
#
# :Number of Attributes: 8 numeric, predictive attributes and the target
#
# :Attribute Information:
#     - MedInc        median income in block group
#     - HouseAge      median house age in block group
#     - AveRooms      average number of rooms per household
#     - AveBedrms     average number of bedrooms per household
#     - Population    block group population
#     - AveOccup      average number of household members
#     - Latitude      block group latitude
#     - Longitude     block group longitude
#
# :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# https://www.dcc.fc.up.pt/~ltorgo/Regression/cal_housing.html
#
# The target variable is the median house value for California districts,
# expressed in hundreds of thousands of dollars ($100,000).
#
# ...

# %%
print(cali.feature_names)
print(cali.data)
# Out:
# ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude']
# [[   8.3252       41.            6.98412698 ...    2.55555556
#     37.88       -122.23      ]
#  [   8.3014       21.            6.23813708 ...    2.10984183
#     37.86       -122.22      ]
#  [   7.2574       52.            8.28813559 ...    2.80225989
#     37.85       -122.24      ]
#  ...
#  [   1.7          17.            5.20554273 ...    2.3256351
#     39.43       -121.22      ]
#  [   1.8672       18.            5.32951289 ...    2.12320917
#     39.43       -121.32      ]
#  [   2.3886       16.            5.25471698 ...    2.61698113
#     39.37       -121.24      ]]

# %%
print(cali.target_names)
print(cali.target)
# Out:
# ['MedHouseVal']
# [4.526 3.585 3.521 ... 0.923 0.847 0.894]

# %% [markdown]
# ## Preparing The Dataset

# %%
df=pd.DataFrame(cali.data, columns=cali.feature_names)
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
df['Price']=cali.target

# %%
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  Price
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MedInc      20640 non-null  float64
#  1   HouseAge    20640 non-null  float64
#  2   AveRooms    20640 non-null  float64
#  3   AveBedrms   20640 non-null  float64
#  4   Population  20640 non-null  float64
#  5   AveOccup    20640 non-null  float64
#  6   Latitude    20640 non-null  float64
#  7   Longitude   20640 non-null  float64
#  8   Price       20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %%
## Summarizing the stat
df.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude         Price
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# ...

# %%
## Check the missing values
df.isnull().sum()
# Out:
# MedInc        0
# HouseAge      0
# AveRooms      0
# AveBedrms     0
# Population    0
# AveOccup      0
# Latitude      0
# Longitude     0
# Price         0
# dtype: int64

# %%
### Exploratory Data Analysis
## Correlation

df.corr()
# Out:
#               MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc      1.000000 -0.119034  0.326895  -0.062040    0.004834  0.018766
# HouseAge   -0.119034  1.000000 -0.153277  -0.077747   -0.296244  0.013191
# AveRooms    0.326895 -0.153277  1.000000   0.847621   -0.072213 -0.004852
# AveBedrms  -0.062040 -0.077747  0.847621   1.000000   -0.066197 -0.006181
# Population  0.004834 -0.296244 -0.072213  -0.066197    1.000000  0.069863
# AveOccup    0.018766  0.013191 -0.004852  -0.006181    0.069863  1.000000
# Latitude   -0.079809  0.011173  0.106389   0.069721   -0.108785  0.002366
# Longitude  -0.015176 -0.108197 -0.027540   0.013344    0.099773  0.002476
# Price       0.688075  0.105623  0.151948  -0.046701   -0.024650 -0.023737
#
#             Latitude  Longitude     Price
# MedInc     -0.079809  -0.015176  0.688075
# HouseAge    0.011173  -0.108197  0.105623
# AveRooms    0.106389  -0.027540  0.151948
# AveBedrms   0.069721   0.013344 -0.046701
# ...

# %%
plt.scatter(df['MedInc'],df['Price'])
plt.xlabel('MedInc')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
sns.regplot(x='MedInc',y='Price',data=df)
# Out:
# <Axes: xlabel='MedInc', ylabel='Price'>

# %%
sns.regplot(x='AveRooms',y='Price',data=df)
# Out:
# <Axes: xlabel='AveRooms', ylabel='Price'>

# %%
sns.regplot(x='HouseAge',y='Price',data=df)
# Out:
# <Axes: xlabel='HouseAge', ylabel='Price'>

# %% [markdown]
# ## Feature Engineering

# %%
# Remove capped prices 
df = df[df['Price'] < 5.0]

# Cap AveRooms at 80th 
df = df[df['AveRooms'] < df['AveRooms'].quantile(0.8)]

# %%
## Independent and Dependent Features

X = df.iloc[:,:-1]
y=np.log(df.iloc[:,-1])

# %%
X.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 5  4.0368      52.0  4.761658   1.103627       413.0  2.139896     37.85
# 6  3.6591      52.0  4.931907   0.951362      1094.0  2.128405     37.84
# 7  3.1200      52.0  4.797527   1.061824      1157.0  1.788253     37.84
# 8  2.0804      42.0  4.294118   1.117647      1206.0  2.026891     37.84
#
#    Longitude
# 3    -122.25
# 5    -122.25
# 6    -122.25
# 7    -122.25
# 8    -122.26

# %%
y
# Out:
# 3        1.227592
# 5        0.992140
# 6        1.095942
# 7        0.881285
# 8        0.818457
#            ...
# 20635   -0.247180
# 20636   -0.260067
# 20637   -0.080126
# 20638   -0.166055
# 20639   -0.112050
# Name: Price, Length: 15717, dtype: float64

# %%
## Train Test Split
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3,random_state=42)

# %%
X_train
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 17218  2.1250      52.0  3.591912   1.062500       412.0  1.514706     34.43
# 3395   4.1964      40.0  5.819672   1.169399       605.0  3.306011     34.26
# 15515  5.4819      12.0  5.759346   0.962617      1226.0  2.864486     33.17
# 13001  2.5199      16.0  3.971322   1.104738      1550.0  1.932668     38.67
# 13605  3.8906      30.0  5.630814   1.020349       945.0  2.747093     34.17
# ...       ...       ...       ...        ...         ...       ...       ...
# 6496   4.6467      23.0  5.629758   1.100346      1279.0  4.425606     34.08
# 17502  2.8971      37.0  4.077540   0.970588      1075.0  2.874332     37.36
# 6769   3.9485      52.0  5.440252   1.035220      1927.0  2.423899     34.10
# 1089   1.7426      33.0  4.993318   1.151448      1160.0  2.583519     39.73
# 8895   3.6769      31.0  4.234899   1.084564      1208.0  1.621477     34.03
#
#        Longitude
# 17218    -119.70
# ...

# %% [markdown]
# ## Model Training

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor

pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('model', RandomForestRegressor(n_estimators=100, random_state=42))
])

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('model', RandomForestRegressor(random_state=42))])

# %%
feature_importance = pd.Series(pipeline.named_steps['model'].feature_importances_, index=df.columns[:-1])
print(feature_importance.sort_values(ascending=False))
# Out:
# MedInc        0.342479
# Longitude     0.203858
# Latitude      0.199387
# AveOccup      0.126772
# HouseAge      0.037958
# AveRooms      0.035965
# Population    0.029153
# AveBedrms     0.024428
# dtype: float64

# %%
## On which params the model has been trained
pipeline.named_steps['model'].get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': None,
#  'max_features': 1.0,
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 42,
#  'verbose': 0,
#  'warm_start': False}

# %%
## Prediction with Test Data
pred = pipeline.predict(X_test)

# %%
pred
# Out:
# array([ 1.00813937, -0.18071115,  0.74831918, ...,  0.20394366,
#         0.65447817, -0.0716725 ], shape=(4716,))

# %% [markdown]
# ## Assumptions

# %%
## Plot a scatter plot for the prediction
plt.scatter(y_test,pred)

# %%
## Residuals
residuals=y_test-pred

# %%
residuals
# Out:
# 17965   -0.230192
# 10690   -0.038689
# 3738    -0.034389
# 18637    0.411536
# 100      0.249011
#            ...
# 8201    -0.190525
# 6422    -0.050691
# 9586    -0.008377
# 19143   -0.162835
# 5219     0.046355
# Name: Price, Length: 4716, dtype: float64

# %%
## Plot residuals
sns.displot(residuals, kind="kde")

# %%
## Scatter plot with respect to prediction and residuals
plt.scatter(pred,residuals)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

print(mean_absolute_error(y_test,pred))
print(mean_squared_error(y_test,pred))
print(np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# 0.1518511201375961
# 0.04749974575745719
# 0.2179443639038578

# %% [markdown]
# ## R square and adjusted R square
# Formula
#
# **R^2 = 1 - SSR/SST**
#
# R^2 = coefficent of determination
# SSR = sum of squares of residuals
# SST = total sum of squares

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,pred)
print(score)
# Out:
# 0.8214999385159227

# %% [markdown]
# **Adjusted R2 = 1 - [(1-R2)*(n-1)/(n-k-1)]**

# %%
1-(1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
# Out:
# 0.8211965604636872

# %% [markdown]
# ## New Data Prediction

# %%
new_data = pd.DataFrame(
    cali.data[1].reshape(1,-1), 
    columns=cali.feature_names  
)
new_data
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3014      21.0  6.238137    0.97188      2401.0  2.109842     37.86
#
#    Longitude
# 0    -122.22

# %%
prediction = pipeline.predict(new_data)
print(f"Predicted Price: {np.exp(prediction[0]):.3f}")  
print(f"Actual Price:    {cali.target[1]:.3f}")
# Out:
# Predicted Price: 2.964
# Actual Price:    3.585

# %% [markdown]
# ## Saving The Model File For Deployment

# %%
joblib.dump(pipeline, 'rdfmodel.pkl')
# Out:
# ['rdfmodel.pkl']

# %%
model = joblib.load('rdfmodel.pkl')
